# %%
import pandas as pd
import json

# %%
def df_to_geojson(df, properties, lat='Latitude', lon='Longitude'):
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}
        feature['geometry']['coordinates'] = [row[lon],row[lat]]
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

# %%
divvy = pd.read_csv('historical.csv')

# %%
locations = divvy[['ID','Latitude','Longitude','Station Name','Address']].drop_duplicates('ID').sort_values('ID')

# %%
geo_json = df_to_geojson(locations, ['ID','Station Name','Address'])

# %%
output_filename = 'sites.js'
with open(output_filename, 'w') as output_file:
    output_file.write('var sites = ')
    json.dump(geo_json, output_file, indent=2)

# %%
divvy[['ID','Latitude','Longitude','Station Name','Address']]
# Out:
#           ID   Latitude  Longitude                         Station Name  \
# 0         66  41.885637 -87.641823                 Clinton St & Lake St
# 1         66  41.885637 -87.641823                 Clinton St & Lake St
# 2        126  41.911974 -87.631942                 Clark St & North Ave
# 3        127  41.925905 -87.649260          Lincoln Ave & Fullerton Ave
# 4        140  41.898969 -87.629912          Dearborn Pkwy & Delaware Pl
# 5        141  41.915689 -87.634600               Clark St & Lincoln Ave
# 6        142  41.894503 -87.617854                 McClurg Ct & Erie St
# 7        143  41.922167 -87.638888            Sedgwick St & Webster Ave
# 8        144  41.921822 -87.644140            Larrabee St & Webster Ave
# 9        145  41.898587 -87.621915  Mies van der Rohe Way & Chestnut St
# 10       146  41.877945 -87.662007             Loomis St & Jackson Blvd
# 11       148  41.834734 -87.625813                   State St & 33rd St
# 12       149  41.834900 -87.617930                Calumet Ave & 33rd St
# 13       128  41.895769 -87.677220              Damen Ave & Chicago Ave
# 14       129  41.857556 -87.661535            Blue Island Ave & 18th St
# 15       130  41.903310 -87.676950              Damen Ave & Division St
# 16       131  41.939365 -87.668385            Lincoln Ave & Belmont Ave
# 17       132  41.849237 -87.631715              Wentworth Ave & 24th St
# 18       133  41.889177 -87.638506             Kingsbury St & Kinzie St
# 19       134  41.877749 -87.649633             Peoria St & Jackson Blvd
# 20       136  41.865054 -87.656959                 Racine Ave & 13th St
# 21       137  41.862378 -87.651062                 Morgan Ave & 14th Pl
# 22       138  41.904613 -87.640552           Clybourn Ave & Division St
# 23       103  41.871467 -87.640949             Clinton St & Polk St (*)
# 24        44  41.884730 -87.627734               State St & Randolph St
# 25        45  41.876243 -87.624426         Michigan Ave & Congress Pkwy
# 26        46  41.899930 -87.634430                 Wells St & Walton St
# 27        48  41.897764 -87.642884           Larrabee St & Kingsbury St
# 28        26  41.891020 -87.617300             McClurg Ct & Illinois St
# 29        27  41.910210 -87.643500              Larrabee St & North Ave
# ...      ...        ...        ...                                  ...
# 7065735  112  41.883668 -87.648670               Green St & Randolph St
# 7065736   72  41.860384 -87.625813                 Wabash Ave & 16th St
# 7065737  122  41.875010 -87.673280            Ogden Ave & Congress Pkwy
# 7065738  123  41.922695 -87.697153       California Ave & Milwaukee Ave
# 7065739  124  41.855048 -87.675726             Damen Ave & Cullerton St
# 7065740   57  41.867118 -87.641088            Clinton St & Roosevelt Rd
# 7065741   69  41.909396 -87.677692               Damen Ave & Pierce Ave
# 7065742   16  41.910337 -87.670072              Paulina Ave & North Ave
# 7065743   81  41.884241 -87.629634                   Daley Center Plaza
# 7065744   23  41.902924 -87.637715              Orleans St & Elm St (*)
# 7065745   19  41.869417 -87.660996            Loomis St & Taylor St (*)
# 7065746   35  41.892278 -87.612043              Streeter Dr & Grand Ave
# 7065747   18  41.883132 -87.637321            Wacker Dr & Washington St
# 7065748   25  41.897660 -87.623510            Michigan Ave & Pearson St
# 7065749   26  41.890359 -87.617532             McClurg Ct & Illinois St
# 7065750   88  41.884069 -87.656853             Racine Ave & Randolph St
# 7065751   84  41.891578 -87.648384            Milwaukee Ave & Grand Ave
# 7065752  115  41.936266 -87.652662       Sheffield Ave & Wellington Ave
# 7065753   31  41.896776 -87.635633            Franklin St & Chicago Ave
# 7065754  114  41.949399 -87.654529         Sheffield Ave & Waveland Ave
# 7065755  116  41.915520 -87.687022          Western Ave & Winnebago Ave
# 7065756  147  41.845687 -87.622481                Indiana Ave & 26th St
# 7065757   97  41.865312 -87.617867                         Field Museum
# 7065758   20  41.910522 -87.653106         Sheffield Ave & Kingsbury St
# 7065759   72  41.860384 -87.625813                 Wabash Ave & 16th St
# 7065760   46  41.899930 -87.634430                 Wells St & Walton St
# 7065761   46  41.899930 -87.634430                 Wells St & Walton St
# 7065762   72  41.860384 -87.625813                 Wabash Ave & 16th St
# 7065763   62  41.851375 -87.618835                      McCormick Place
# 7065764  147  41.845687 -87.622481                Indiana Ave & 26th St
#
#                                      Address
# 0                       Clinton St & Lake St
# 1                       Clinton St & Lake St
# 2                       Clark St & North Ave
# 3                Lincoln Ave & Fullerton Ave
# 4                Dearborn Pkwy & Delaware Pl
# 5                     Clark St & Lincoln Ave
# 6                       McClurg Ct & Erie St
# 7                  Sedgwick St & Webster Ave
# 8                  Larrabee St & Webster Ave
# 9        Mies van der Rohe Way & Chestnut St
# 10                  Loomis St & Jackson Blvd
# 11                        State St & 33rd St
# 12                     Calumet Ave & 33rd St
# 13                   Damen Ave & Chicago Ave
# 14                 Blue Island Ave & 18th St
# 15                   Damen Ave & Division St
# 16                 Lincoln Ave & Belmont Ave
# 17                   Wentworth Ave & 24th St
# 18                  Kingsbury St & Kinzie St
# 19                  Peoria St & Jackson Blvd
# 20                      Racine Ave & 13th St
# 21                      Morgan Ave & 14th Pl
# 22                Clybourn Ave & Division St
# 23                  Clinton St & Polk St (*)
# 24                    State St & Randolph St
# 25              Michigan Ave & Congress Pkwy
# 26                      Wells St & Walton St
# 27                Larrabee St & Kingsbury St
# 28                  McClurg Ct & Illinois St
# 29                   Larrabee St & North Ave
# ...                                      ...
# 7065735               Green St & Randolph St
# 7065736                 Wabash Ave & 16th St
# 7065737            Ogden Ave & Congress Pkwy
# 7065738       California Ave & Milwaukee Ave
# 7065739             Damen Ave & Cullerton St
# 7065740            Clinton St & Roosevelt Rd
# 7065741               Damen Ave & Pierce Ave
# 7065742              Paulina Ave & North Ave
# 7065743                   Daley Center Plaza
# 7065744              Orleans St & Elm St (*)
# 7065745            Loomis St & Taylor St (*)
# 7065746              Streeter Dr & Grand Ave
# 7065747            Wacker Dr & Washington St
# 7065748            Michigan Ave & Pearson St
# 7065749             McClurg Ct & Illinois St
# 7065750             Racine Ave & Randolph St
# 7065751            Milwaukee Ave & Grand Ave
# 7065752       Sheffield Ave & Wellington Ave
# 7065753            Franklin St & Chicago Ave
# 7065754         Sheffield Ave & Waveland Ave
# 7065755          Western Ave & Winnebago Ave
# 7065756                Indiana Ave & 26th St
# 7065757                         Field Museum
# 7065758         Sheffield Ave & Kingsbury St
# 7065759                 Wabash Ave & 16th St
# 7065760                 Wells St & Walton St
# 7065761                 Wells St & Walton St
# 7065762                 Wabash Ave & 16th St
# 7065763                      McCormick Place
# 7065764                Indiana Ave & 26th St
#
# [7065765 rows x 5 columns]
